# %%
from google.colab import drive  
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### YOLOv7파일 다운로드 및 설치

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1127, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 1127 (delta 12), reused 13 (delta 3), pack-reused 1098
# Receiving objects: 100% (1127/1127), 69.96 MiB | 32.78 MiB/s, done.
# Resolving deltas: 100% (523/523), done.

# %%
# !cd yolov7
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.1 MB 5.2 MB/s
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ...

# %%
# !cd yoloyv7 pip install -r requirements.txt
# !sudo apt install -y zip htop screen libgl1-mesa-glx
# Out:
# /bin/bash: line 0: cd: too many arguments
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zip is already the newest version (3.0-11build1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# Suggested packages:
#   strace byobu | screenie | iselect ncurses-term
# The following NEW packages will be installed:
#   htop libgl1-mesa-glx screen
# 0 upgraded, 3 newly installed, 0 to remove and 20 not upgraded.
# Need to get 663 kB of archives.
# After this operation, 1,311 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 htop amd64 2.1.0-3 [80.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 screen amd64 4.6.2-1ubuntu1.1 [577 kB]
# ...

# %% [markdown]
# ### YOLOv7 모델 학습 (train)

# %%
# !cd yolov7; python3 train.py \
  --workers 8 \
  --batch-size 10 \
  --data '/content/parking_lot.yaml' \
  --img 640 640 \
  --weights yolov7.pt \
  --name yolov7 \
  --hyp data/hyp.scratch.custom.yaml\
  --epochs 100
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=10, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/content/parking_lot.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov72', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=10, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !cp -r /content/yolov7/runs/train/yolov72 /content/gdrive/MyDrive/KT_AIVLE/빅프로젝트
